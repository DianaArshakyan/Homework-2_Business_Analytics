# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from statsmodels.discrete.discrete_model import Logit
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

# %% [markdown]
# **Problem 1**

# %%
data = pd.read_excel("Employee_attrition.xlsx")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate                Department  \
# 0   41       Yes      Travel_Rarely       1102                     Sales
# 1   49        No  Travel_Frequently        279  Research_and_Development
# 2   37       Yes      Travel_Rarely       1373  Research_and_Development
# 3   33        No  Travel_Frequently       1392  Research_and_Development
# 4   27        No      Travel_Rarely        591  Research_and_Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life_Sciences              1               1
# 1                 8          1  Life_Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life_Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null object
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# Over18                      1470 non-null object
# OverTime                    1470 non-null object
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(26), object(9)
# memory usage: 402.0+ KB

# %%
data_numeric = data.select_dtypes(exclude="object")
data_object = data.select_dtypes(include="object")

# %%
data_object.head()
# Out:
#   Attrition     BusinessTravel                Department EducationField  \
# 0       Yes      Travel_Rarely                     Sales  Life_Sciences
# 1        No  Travel_Frequently  Research_and_Development  Life_Sciences
# 2       Yes      Travel_Rarely  Research_and_Development          Other
# 3        No  Travel_Frequently  Research_and_Development  Life_Sciences
# 4        No      Travel_Rarely  Research_and_Development        Medical
#
#    Gender                JobRole MaritalStatus Over18 OverTime
# 0  Female        Sales_Executive        Single      Y      Yes
# 1    Male     Research_Scientist       Married      Y       No
# 2    Male  Laboratory_Technician        Single      Y      Yes
# 3  Female     Research_Scientist       Married      Y      Yes
# 4    Male  Laboratory_Technician       Married      Y       No

# %%
data_numeric.var()==0
# Out:
# Age                         False
# DailyRate                   False
# DistanceFromHome            False
# Education                   False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobSatisfaction             False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours                True
# StockOptionLevel            False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# dtype: bool

# %%
data_numeric.EmployeeCount.var()==0
# Out:
# True

# %%
# we have two variables ("StandardHouse", "EmployeeCount") that should be dropped, as they have no variance.

# %%
data_numeric = data_numeric.drop(["StandardHours", "EmployeeCount"], axis = 1)

# %%
for i in data_object.columns:
    print(data_object[i].unique())
# Out:
# ['Yes' 'No']
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ['Sales' 'Research_and_Development' 'Human_Resources']
# ['Life_Sciences' 'Other' 'Medical' 'Marketing' 'Technical_Degree'
#  'Human_Resources']
# ['Female' 'Male']
# ['Sales_Executive' 'Research_Scientist' 'Laboratory_Technician'
#  'Manufacturing_Director' 'Healthcare_Representative' 'Manager'
#  'Sales_Representative' 'Research_Director' 'Human_Resources']
# ['Single' 'Married' 'Divorced']
# ['Y']
# ['Yes' 'No']

# %%
# we see that there is an object variable("Over18") with one category("Y"), so we should drop that column.

# %%
data_object = data_object.drop(["Over18"], axis = 1)

# %%
data_dummies = pd.get_dummies(data_object, prefix=data_object.columns, drop_first=True)
# we convert object variables into dummy variables

# %%
sns.heatmap(data_numeric.corr())

# %%
plt.figure(figsize=(16, 14)) 
sns.heatmap(data_numeric.corr().abs().round(2), annot=True)
plt.show()

# %%
data_final = data_numeric.join(data_dummies)

# %%
# Now we want to see which correlations are above or equal to 75% in absolute values

# %%
plt.figure(figsize=(12, 10)) 
sns.heatmap(data_numeric.corr().abs()>=0.75)
plt.show()

# %%
# We see that there are variables that have correlations higher than 75%, so we should delete them

# %%
del data_numeric["YearsAtCompany"]

# %%
del data_numeric["TotalWorkingYears"]

# %%
del data_numeric["JobLevel"]

# %%
del data_numeric["PercentSalaryHike"]

# %%
plt.figure(figsize=(12, 10)) 
sns.heatmap(data_numeric.corr().abs()>=0.75)
plt.show()

# %%
data_final = data_numeric.join(data_dummies)

# %%
data_final.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41       1102                 1          2               1
# 1   49        279                 8          1               2
# 2   37       1373                 2          2               4
# 3   33       1392                 3          4               5
# 4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobSatisfaction  \
# 0                        2          94               3                4
# 1                        3          61               2                2
# 2                        4          92               2                3
# 3                        4          56               3                3
# 4                        1          40               3                2
#
#    MonthlyIncome      ...       JobRole_Laboratory_Technician  \
# 0           5993      ...                                   0
# 1           5130      ...                                   0
# 2           2090      ...                                   1
# 3           2909      ...                                   0
# 4           3468      ...                                   1
#
#    JobRole_Manager  JobRole_Manufacturing_Director  JobRole_Research_Director  \
# 0                0                               0                          0
# 1                0                               0                          0
# 2                0                               0                          0
# 3                0                               0                          0
# 4                0                               0                          0
#
#    JobRole_Research_Scientist  JobRole_Sales_Executive  \
# 0                           0                        1
# 1                           1                        0
# 2                           0                        0
# 3                           1                        0
# 4                           0                        0
#
#    JobRole_Sales_Representative  MaritalStatus_Married  MaritalStatus_Single  \
# 0                             0                      0                     1
# 1                             0                      1                     0
# 2                             0                      0                     1
# 3                             0                      1                     0
# 4                             0                      1                     0
#
#    OverTime_Yes
# 0             1
# 1             0
# 2             1
# 3             1
# 4             0
#
# [5 rows x 42 columns]

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
data_final.Attrition_Yes.value_counts()/len(data_final)*100
# Out:
# 0    83.877551
# 1    16.122449
# Name: Attrition_Yes, dtype: float64

# %%
# We see that about 84% of employees stay in their jobs.

# %%
Y = data_final.Attrition_Yes
X = data_final.drop("Attrition_Yes",axis=1)
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
formula = 'Y~'+'+'.join(X.columns.tolist())
formula
# Out:
# 'Y~_Travel_Frequently+BusinessTravel_Travel_Rarely+Department_Research_and_Development+Department_Sales+EducationField_Life_Sciences+EducationField_Marketing+EducationField_Medical+EducationField_Other+EducationField_Technical_Degree+Gender_Male+JobRole_Human_Resources+JobRole_Laboratory_Technician+JobRole_Manager+JobRole_Manufacturing_Director+JobRole_Research_Director+JobRole_Research_Scientist+JobRole_Sales_Executive+JobRole_Sales_Representative+MaritalStatus_Married+MaritalStatus_Single+OverTime_Yes'

# %%
logit = Logit.from_formula(formula = formula, data = data_final).fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.294829
#          Iterations: 35
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
logit.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                       Results: Logit
# ==========================================================================================
# Model:                       Logit                    Pseudo R-squared:         0.333
# Dependent Variable:          Y                        AIC:                      950.7961
# Date:                        2018-11-10 22:23         BIC:                      1173.1029
# No. Observations:            1470                     Log-Likelihood:           -433.40
# Df Model:                    41                       LL-Null:                  -649.29
# Df Residuals:                1428                     LLR p-value:              1.1599e-66
# Converged:                   0.0000                   Scale:                    1.0000
# No. Iterations:              35.0000
# ------------------------------------------------------------------------------------------
#                                      Coef.    Std.Err.    z    P>|z|    [0.025     0.975]
# ------------------------------------------------------------------------------------------
# Intercept                           -10.8938 1023.9605 -0.0106 0.9915 -2017.8195 1996.0319
# Age                                  -0.0432    0.0122 -3.5413 0.0004    -0.0670   -0.0193
# DailyRate                            -0.0003    0.0002 -1.3876 0.1653    -0.0007    0.0001
# DistanceFromHome                      0.0438    0.0107  4.1021 0.0000     0.0229    0.0647
# Education                             0.0093    0.0877  0.1066 0.9151    -0.1625    0.1812
# EmployeeNumber                       -0.0001    0.0002 -0.8985 0.3689    -0.0004    0.0002
# EnvironmentSatisfaction              -0.4187    0.0824 -5.0831 0.0000    -0.5802   -0.2573
# HourlyRate                            0.0016    0.0044  0.3699 0.7114    -0.0070    0.0102
# JobInvolvement                       -0.5277    0.1212 -4.3547 0.0000    -0.7653   -0.2902
# JobSatisfaction                      -0.3978    0.0805 -4.9426 0.0000    -0.5556   -0.2401
# MonthlyIncome                        -0.0000    0.0001 -0.5422 0.5877    -0.0001    0.0001
# MonthlyRate                           0.0000    0.0000  0.3369 0.7362    -0.0000    0.0000
# NumCompaniesWorked                    0.1650    0.0373  4.4253 0.0000     0.0919    0.2380
# PerformanceRating                    -0.0989    0.2501 -0.3953 0.6926    -0.5891    0.3914
# RelationshipSatisfaction             -0.2515    0.0823 -3.0570 0.0022    -0.4128   -0.0903
# StockOptionLevel                     -0.1900    0.1575 -1.2059 0.2278    -0.4987    0.1188
# TrainingTimesLastYear                -0.1835    0.0727 -2.5252 0.0116    -0.3260   -0.0411
# WorkLifeBalance                      -0.3637    0.1234 -2.9459 0.0032    -0.6056   -0.1217
# YearsInCurrentRole                   -0.1156    0.0422 -2.7412 0.0061    -0.1983   -0.0329
# YearsSinceLastPromotion               0.2008    0.0404  4.9719 0.0000     0.1216    0.2799
# YearsWithCurrManager                 -0.0985    0.0416 -2.3677 0.0179    -0.1800   -0.0170
# BusinessTravel_Travel_Frequently      1.8665    0.4078  4.5773 0.0000     1.0673    2.6657
# BusinessTravel_Travel_Rarely          0.9709    0.3761  2.5816 0.0098     0.2338    1.7081
# Department_Research_and_Development  13.5900 1023.9596  0.0133 0.9894 -1993.3340 2020.5140
# Department_Sales                     13.3493 1023.9597  0.0130 0.9896 -1993.5749 2020.2734
# EducationField_Life_Sciences         -0.7139    0.8014 -0.8909 0.3730    -2.2845    0.8567
# EducationField_Marketing             -0.3214    0.8490 -0.3786 0.7050    -1.9855    1.3427
# EducationField_Medical               -0.7941    0.8006 -0.9919 0.3213    -2.3632    0.7750
# EducationField_Other                 -0.8147    0.8605 -0.9467 0.3438    -2.5013    0.8720
# EducationField_Technical_Degree       0.1744    0.8190  0.2129 0.8314    -1.4309    1.7797
# Gender_Male                           0.4042    0.1837  2.2003 0.0278     0.0441    0.7642
# JobRole_Human_Resources              15.0723 1023.9597  0.0147 0.9883 -1991.8518 2021.9964
# JobRole_Laboratory_Technician         1.5890    0.4727  3.3613 0.0008     0.6624    2.5155
# JobRole_Manager                       0.5727    0.8707  0.6578 0.5107    -1.1337    2.2792
# JobRole_Manufacturing_Director        0.2432    0.5357  0.4540 0.6499    -0.8068    1.2933
# JobRole_Research_Director            -0.9054    0.9684 -0.9349 0.3498    -2.8034    0.9926
# JobRole_Research_Scientist            0.6695    0.4784  1.3995 0.1617    -0.2681    1.6072
# JobRole_Sales_Executive               1.3808    1.1144  1.2391 0.2153    -0.8034    3.5650
# JobRole_Sales_Representative          2.3274    1.1654  1.9971 0.0458     0.0433    4.6116
# MaritalStatus_Married                 0.3111    0.2654  1.1722 0.2411    -0.2091    0.8313
# MaritalStatus_Single                  1.1578    0.3435  3.3707 0.0007     0.4846    1.8310
# OverTime_Yes                          1.9507    0.1919 10.1665 0.0000     1.5746    2.3268
# ==========================================================================================
#
# """

# %%
# According to summary of model we can see that there are some statistically significant variables that have 
# p-value less than 0.05. For example, let's interpret the coefficient YearsAtCompany(0.0961):
# One year increase at company will increase employee attrition by 0.0961, ceteris paribus.

# %%
logit_sk = LogisticRegression()

# %%
logit_sk = logit_sk.fit(x_train,y_train)

# %%
logit_sk.score(x_test,y_test)
# Out:
# 0.8777173913043478

# %%
# Our model is accurate by around 88%.

# %% [markdown]
# **Problem 2**

# %%
tree_1 = DecisionTreeClassifier(random_state = 42)

# %%
tree_1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
tree_1.score(x_train, y_train)
# Out:
# 1.0

# %%
tree_1.score(x_test, y_test)
# Out:
# 0.782608695652174

# %%
# This result is not desired as it is lower than benchmark.

# %%
importances = tree_1.feature_importances_
importances = pd.DataFrame(data=importances, index=X.columns, columns=['importances'])

# %%
importances.sort_values(by = "importances", ascending=False)
# Out:
#                                      importances
# MonthlyIncome                           0.142486
# DailyRate                               0.090195
# EmployeeNumber                          0.080821
# OverTime_Yes                            0.075114
# Age                                     0.069635
# YearsInCurrentRole                      0.051618
# HourlyRate                              0.045605
# NumCompaniesWorked                      0.044997
# YearsSinceLastPromotion                 0.040302
# MonthlyRate                             0.038930
# JobInvolvement                          0.032134
# YearsWithCurrManager                    0.030419
# WorkLifeBalance                         0.029573
# DistanceFromHome                        0.029519
# MaritalStatus_Single                    0.027735
# EnvironmentSatisfaction                 0.025279
# StockOptionLevel                        0.021126
# JobSatisfaction                         0.018469
# TrainingTimesLastYear                   0.016508
# Department_Sales                        0.015159
# RelationshipSatisfaction                0.013673
# JobRole_Sales_Executive                 0.010704
# EducationField_Medical                  0.009731
# BusinessTravel_Travel_Frequently        0.009180
# Education                               0.007538
# JobRole_Research_Director               0.005588
# JobRole_Research_Scientist              0.004790
# MaritalStatus_Married                   0.004258
# EducationField_Technical_Degree         0.003141
# JobRole_Sales_Representative            0.003007
# JobRole_Human_Resources                 0.002767
# JobRole_Manufacturing_Director          0.000000
# Department_Research_and_Development     0.000000
# EducationField_Life_Sciences            0.000000
# EducationField_Marketing                0.000000
# JobRole_Laboratory_Technician           0.000000
# BusinessTravel_Travel_Rarely            0.000000
# Gender_Male                             0.000000
# EducationField_Other                    0.000000
# PerformanceRating                       0.000000
# JobRole_Manager                         0.000000

# %%
tree_2 = DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 100, random_state = 42)
tree_2.fit(x_train,y_train)
tree_2.score(x_test,y_test)
# Out:
# 0.8532608695652174

# %%
# Again we see that Logistic Regression gives higher accuracy than Decision tree model.

# %%
# If we want to see the decision tree.
tree_gr = export_graphviz(tree_1, out_file = "tree2.dot", class_names = True, feature_names = X.columns, filled = True)
